# %% [markdown]
# ## 1. 기사를 가져와 형태소 분석하기 위해 제목과 기사내용 토큰화 및 품사부착

# %%
import pandas as pd 
import numpy as np
food_news = pd.read_csv('C:/Users/이상은/food_news.csv')
food_news = food_news.drop(columns  = 'Unnamed: 0')
food_news.head()
# Out:
#          date                               title   press  \
# 0  2020.09.10       경북도, ‘코로나 면역 효자’ 김치산업 제대로 키운다    국민일보
# 1  2020.09.09  경북도 "김치산업 중심지 될 것"...5년간 1283억원 투입     뉴시스
# 2  2020.09.10     국민의힘, 정기국회 중점 입법…코로나·부동산법 우선 처리     뉴시스
# 3  2020.09.04        국가식품클러스터 우수제품 온라인 판매…식품축제 개막  연합뉴스TV
# 4  2020.09.05     ‘우리농수산식품모음집’에서 추석 선물세트 고민 해결하세요    세계일보
#
#                                              content  \
# 0  면역력 관심 반영 수출·내수 급증…  2024년까지 1283억 투입 집중육성경북도는...
# 1  풍산김치 (사진=안동시 제공)[안동=뉴시스] 류상현 기자 = 경북도가 김치산업 육성...
# 2  국민의힘 정책위, 정기국회 5대 분야 30대 과제 선정'조국 아빠찬스' '윤미향 방...
# 3  동영상 뉴스\n\n\n\n\n\n\n\t\n\t전북 익산시 국가식품클러스터 입주 기...
# 4  코로나19의 시련 속에도 추석은 다가온다. 고마운 이들에게 어떤 선물로 마음을 전해...
#
#                                                  url
# 0  https://search.naver.com/search.naver?&where=n...
# 1  https://search.naver.com/search.naver?&where=n...
# 2  https://search.naver.com/search.naver?&where=n...
# 3  https://search.naver.com/search.naver?&where=n...
# 4  https://search.naver.com/search.naver?&where=n...

# %%
#불필요한 단어들 토큰화하기 전에 제거 : 함수 만들어주기 --> 함수를 food_new['content']에다 적용하기 
import re 
def preprocess(text):
    text = re.sub('\t|\n|\r','',text).strip()
    text = re.sub('구독해주세요','',text).strip()
    text = re.sub('구독하기', '', text).strip()
    text = re.sub('무단 전재 및 재배포 금지', '', text).strip()
    text = re.sub('바로가기', '', text).strip()
    text = re.sub('All rights reserved', '', text).strip()
    return text
food_news['content'] = food_news['content'].map(lambda x : preprocess(x))

# %%
food_news.head(10)
# Out:
#          date                               title   press  \
# 0  2020.09.10       경북도, ‘코로나 면역 효자’ 김치산업 제대로 키운다    국민일보
# 1  2020.09.09  경북도 "김치산업 중심지 될 것"...5년간 1283억원 투입     뉴시스
# 2  2020.09.10     국민의힘, 정기국회 중점 입법…코로나·부동산법 우선 처리     뉴시스
# 3  2020.09.04        국가식품클러스터 우수제품 온라인 판매…식품축제 개막  연합뉴스TV
# 4  2020.09.05     ‘우리농수산식품모음집’에서 추석 선물세트 고민 해결하세요    세계일보
# 5  2020.09.04             코로나 장기화에… 불 붙은 '밀키트' 전쟁    조선비즈
# 6  2020.09.04               “익산 식품축제 오지 말고 접속하세요”   헤럴드경제
# 7  2020.09.04         농식품 수출은 ‘코로나 특수’ 올 4.9% 늘었다    조선일보
# 8  2020.09.09                대상 'K뷰티'로 이커머스 시장 접속    서울경제
# 9  2020.09.09                     소이오일 마스터를 아십니까.   헤럴드경제
#
#                                              content  \
# 0  면역력 관심 반영 수출·내수 급증…  2024년까지 1283억 투입 집중육성경북도는...
# 1  풍산김치 (사진=안동시 제공)[안동=뉴시스] 류상현 기자 = 경북도가 김치산업 육성...
# 2  국민의힘 정책위, 정기국회 5대 분야 30대 과제 선정'조국 아빠찬스' '윤미향 방...
# 3  동영상 뉴스전북 익산시 국가식품클러스터 입주 기업들의 우수 제품을 온라인으로 판매하...
# 4  코로나19의 시련 속에도 추석은 다가온다. 고마운 이들에게 어떤 선물로 마음을 전해...
# 5  양념·재료·요리법까지…간편함 내세워 승부장바구니 물가 급등해 밀키트 구매가 경제적코...
# 6  식품진흥원 국내 최초 온라인 개최10일까지 42개사 301개 제품 판매한국식품산업클...
# 7  코로나 사태로 우라나라 수출이 ‘직격탄’을 맞았지만, 농식품 수출은 되레 작년보다 ...
# 8  자회사 디에스엔 '100LABS' 론칭바이오 기술·식품관련 인프라 접목목욕용품 등 ...
# 9  출처 : 미국대두협회[헤럴드경제] ‘소이오일 마스터’.다소 생소하지만 단순히 식품을...
#
#                                                  url
# 0  https://search.naver.com/search.naver?&where=n...
# 1  https://search.naver.com/search.naver?&where=n...
# 2  https://search.naver.com/search.naver?&where=n...
# 3  https://search.naver.com/search.naver?&where=n...
# 4  https://search.naver.com/search.naver?&where=n...
# 5  https://search.naver.com/search.naver?&where=n...
# 6  https://search.naver.com/search.naver?&where=n...
# 7  https://search.naver.com/search.naver?&where=n...
# 8  https://search.naver.com/search.naver?&where=n...
# 9  https://search.naver.com/search.naver?&where=n...

# %%
from konlpy.tag import Mecab 
mecab = Mecab()

mecab_tokens = []
for i in range(len(food_news)):
        mecab_tokens.append(mecab.pos(food_news['title'][i])) #토큰화하면서 품사부착 동시에 해줄 수 있음 
        mecab_tokens.append(mecab.pos(food_news["content"][i]))

mecab_tag = []
for token in mecab_tokens: 
    mecab_tag += token

# %%
# mecab_tokens[0] 하면 title에 해당되는 tokens 반환 
# [1]하면 content에 해당되는 tokens 반환

# %% [markdown]
# ## 3. 불용어 처리(Stopword)

# %%
from collections import Counter 
Counter(mecab_tag).most_common()
# Out:
# [(('.', 'SF'), 473),
#  (('을', 'JKO'), 403),
#  ((',', 'SC'), 319),
#  (('다', 'EF'), 303),
#  (('에', 'JKB'), 277),
#  (('의', 'JKG'), 247),
#  (('이', 'JKS'), 236),
#  (('를', 'JKO'), 234),
#  (('고', 'EC'), 233),
#  (('는', 'ETM'), 223),
#  (('하', 'XSV'), 207),
#  (('는', 'JX'), 181),
#  (('으로', 'JKB'), 148),
#  (('등', 'NNB'), 147),
#  (('가', 'JKS'), 141),
#  (('은', 'JX'), 139),
#  (('도', 'JX'), 135),
#  (('로', 'JKB'), 122),
#  (('.', 'SY'), 119),
#  (('식품', 'NNG'), 117),
#  (('있', 'VX'), 113),
#  (('에서', 'JKB'), 105),
#  (('(', 'SSO'), 100),
#  ((')', 'SSC'), 94),
#  (("'", 'SY'), 87),
#  (('들', 'XSN'), 84),
#  (('한', 'XSA+ETM'), 83),
#  (('과', 'JC'), 82),
#  (('이', 'VCP'), 78),
#  (('했', 'XSV+EP'), 76),
#  (('코로나', 'NNP'), 73),
#  (('해', 'XSV+EC'), 72),
#  (('은', 'ETM'), 71),
#  (('‘', 'SY'), 66),
#  (('산업', 'NNG'), 66),
#  (('·', 'SC'), 62),
#  (('"', 'SY'), 61),
#  (('원', 'NNBC'), 60),
#  (('억', 'NR'), 57),
#  (('것', 'NNB'), 57),
#  (('’', 'SY'), 56),
#  (('일', 'NNBC'), 56),
#  (('와', 'JC'), 55),
#  (('지원', 'NNG'), 52),
#  (('▶', 'SY'), 52),
#  (('19', 'SN'), 51),
#  (('%', 'SY'), 51),
#  (('1', 'SN'), 50),
#  (('한', 'XSV+ETM'), 49),
#  (('년', 'NNBC'), 48),
#  (('기', 'ETN'), 48),
#  (('제품', 'NNG'), 48),
#  (('가리비', 'NNG'), 48),
#  (('“', 'SSO'), 47),
#  (('”', 'SSC'), 47),
#  (('어', 'EC'), 46),
#  (('다', 'EC'), 46),
#  (('까지', 'JX'), 45),
#  (('수', 'NNB'), 45),
#  (('월', 'NNBC'), 44),
#  (('시장', 'NNG'), 44),
#  (('게', 'EC'), 44),
#  (('김치', 'NNG'), 43),
#  (('적', 'XSN'), 43),
#  (('및', 'MAJ'), 43),
#  (('며', 'EC'), 42),
#  (('있', 'VV'), 42),
#  (('인', 'VCP+ETM'), 42),
#  (('할', 'XSV+ETM'), 41),
#  (('면', 'EC'), 39),
#  (('만', 'NR'), 39),
#  (('올해', 'NNG'), 39),
#  ((']', 'SSC'), 38),
#  (('화', 'XSN'), 37),
#  (('2', 'SN'), 36),
#  (('[', 'SSO'), 36),
#  (('면서', 'EC'), 34),
#  (('5', 'SN'), 34),
#  (('었', 'EP'), 34),
#  (('늘', 'VV'), 33),
#  (('되', 'XSV'), 33),
#  (('하', 'XSA'), 33),
#  (('한국', 'NNP'), 32),
#  (('사업', 'NNG'), 32),
#  (('기업', 'NNG'), 32),
#  (('학생', 'NNG'), 32),
#  (('온라인', 'NNG'), 31),
#  (('수출', 'NNG'), 30),
#  (('대한', 'VV+ETM'), 30),
#  (('부', 'NNG'), 30),
#  (('업계', 'NNG'), 30),
#  (('오뚜기', 'NNG'), 30),
#  (('된', 'XSV+ETM'), 29),
#  (('한다', 'XSV+EF'), 29),
#  (('경제', 'NNG'), 29),
#  (('받', 'VV'), 28),
#  (('개', 'NNBC'), 28),
#  (('7', 'SN'), 27),
#  (('기자', 'NNG'), 27),
#  (('통해', 'VV+EC'), 27),
#  (('위한', 'VV+ETM'), 26),
#  (('이', 'MM'), 26),
#  (('미국', 'NNP'), 25),
#  (('전형', 'NNG'), 25),
#  (('아', 'EC'), 25),
#  (('탄산', 'NNG'), 25),
#  (('농', 'NNG'), 24),
#  (('국내', 'NNG'), 23),
#  (('집', 'NNG'), 23),
#  (('건강', 'NNG'), 22),
#  (('같', 'VA'), 22),
#  (('증가', 'NNG'), 22),
#  (('10', 'SN'), 22),
#  (('명', 'NNBC'), 22),
#  (('확대', 'NNG'), 21),
#  (('대상', 'NNG'), 21),
#  (('=', 'SY'), 21),
#  (('com', 'SL'), 21),
#  (('하', 'VV'), 21),
#  (('마스터', 'NNG'), 21),
#  (('유산균', 'NNG'), 21),
#  (('@', 'SY'), 20),
#  (('했', 'VV+EP'), 20),
#  (('말', 'NNG'), 20),
#  (('사회', 'NNG'), 20),
#  (('4', 'SN'), 20),
#  (('높', 'VA'), 20),
#  (('분야', 'NNG'), 19),
#  (('생산', 'NNG'), 19),
#  (('네이버', 'NNP'), 19),
#  (('에게', 'JKB'), 19),
#  (('좋', 'VA'), 19),
#  (('6', 'SN'), 19),
#  (('위', 'NNBC'), 19),
#  (('관계자', 'NNG'), 19),
#  (('8', 'SN'), 19),
#  (('호서', 'NNG'), 19),
#  (('…', 'SE'), 18),
#  (('행사', 'NNG'), 18),
#  (('지', 'VX'), 18),
#  (('고', 'JKQ'), 18),
#  (('금지', 'NNG'), 18),
#  (('-', 'SY'), 18),
#  (('추진', 'NNG'), 18),
#  (('소비자', 'NNG'), 18),
#  (('3', 'SN'), 18),
#  (('사태', 'NNG'), 18),
#  (('부터', 'JX'), 18),
#  (('매출', 'NNG'), 18),
#  (('지역', 'NNG'), 18),
#  (('학과', 'NNG'), 18),
#  (('아이스크림', 'NNG'), 18),
#  (('경북', 'NNP'), 17),
#  (('이', 'NP'), 17),
#  (('공급', 'NNG'), 17),
#  (('업체', 'NNG'), 17),
#  (('맛', 'NNG'), 17),
#  (('어린이', 'NNG'), 17),
#  (('지', 'EC'), 17),
#  (('재', 'XPN'), 17),
#  (('뉴시스', 'NNP'), 17),
#  (('수요', 'NNG'), 17),
#  (('서울', 'NNP'), 17),
#  (('한', 'MM'), 17),
#  (('습니다', 'EF'), 17),
#  (('다양', 'NNG'), 17),
#  (('키트', 'NNG'), 17),
#  (('대비', 'NNG'), 17),
#  (('차', 'NNG'), 17),
#  (('최근', 'NNG'), 16),
#  (('위해', 'VV+EC'), 16),
#  (('다', 'VCP+EF'), 16),
#  (('달러', 'NNBC'), 16),
#  (('해외', 'NNG'), 16),
#  (('브랜드', 'NNG'), 16),
#  (('가격', 'NNG'), 16),
#  (('개발', 'NNG'), 16),
#  (('~', 'SY'), 16),
#  (('관련', 'NNG'), 16),
#  (('없', 'VA'), 16),
#  (('더', 'MAG'), 16),
#  (('출시', 'NNG'), 16),
#  (('협회', 'NNG'), 16),
#  (('면접', 'NNG'), 16),
#  (('9', 'SN'), 15),
#  (('대학', 'NNG'), 15),
#  (('먹', 'VV'), 15),
#  (('유통', 'NNG'), 15),
#  (('기간', 'NNG'), 15),
#  (('성', 'XSN'), 15),
#  (('30', 'SN'), 15),
#  (('축제', 'NNG'), 15),
#  (('뉴스', 'NNG'), 15),
#  (('중', 'NNB'), 15),
#  (('만', 'JX'), 15),
#  (('프로그램', 'NNG'), 15),
#  (('육성', 'NNG'), 14),
#  (('제공', 'NNG'), 14),
#  (('확산', 'NNG'), 14),
#  (('가공', 'NNG'), 14),
#  (('또', 'MAG'), 14),
#  (('교육', 'NNG'), 14),
#  (('ⓒ', 'SY'), 14),
#  (('여', 'XSN'), 14),
#  (('보', 'VV'), 14),
#  (('요리', 'NNG'), 14),
#  (('전년', 'NNG'), 14),
#  (('많', 'VA'), 14),
#  (('점', 'NNG'), 14),
#  (('기능', 'NNG'), 14),
#  (('됐', 'XSV+EP'), 14),
#  (('고압가스', 'NNG'), 14),
#  (('장', 'NNG'), 13),
#  (('계획', 'NNG'), 13),
#  (('겠', 'EP'), 13),
#  (('세요', 'EP+EF'), 13),
#  (('성장', 'NNG'), 13),
#  (('준비', 'NNG'), 13),
#  (('피해', 'NNG'), 13),
#  (('을', 'ETM'), 13),
#  (('시작', 'NNG'), 13),
#  (('상품', 'NNG'), 13),
#  (('보다', 'JKB'), 13),
#  (('가장', 'MAG'), 13),
#  (('100', 'SN'), 13),
#  (('뷰티', 'NNG'), 13),
#  (('던', 'ETM'), 13),
#  (('소이', 'NNG'), 13),
#  (('오', 'NR'), 13),
#  (('커피', 'NNG'), 13),
#  (('발효유', 'NNG'), 13),
#  (('장애', 'NNG'), 13),
#  (('따르', 'VV'), 12),
#  (('밝혔', 'VV+EP'), 12),
#  (('국민', 'NNG'), 12),
#  (('간', 'NNG'), 12),
#  (('도움', 'NNG'), 12),
#  (('지난', 'VV+ETM'), 12),
#  (('해', 'XSA+EC'), 12),
#  (('모집', 'NNG'), 12),
#  (('판매', 'NNG'), 12),
#  (('밀', 'VV+ETM'), 12),
#  (('CJ', 'SL'), 12),
#  (('기술', 'NNG'), 12),
#  (('활동', 'NNG'), 12),
#  (('구이', 'NNG'), 12),
#  (('그', 'MM'), 12),
#  (('취소', 'NNG'), 12),
#  (('음료', 'NNG'), 12),
#  (('마련', 'NNG'), 11),
#  (('연구', 'NNG'), 11),
#  (('이후', 'NNG'), 11),
#  (('재료', 'NNG'), 11),
#  (('인기', 'NNG'), 11),
#  (('배포', 'NNG'), 11),
#  (('대', 'XPN'), 11),
#  (('▲', 'SY'), 11),
#  (('경우', 'NNG'), 11),
#  (('관리', 'NNG'), 11),
#  (('/', 'SC'), 11),
#  (('선물', 'NNG'), 11),
#  (('함께', 'MAG'), 11),
#  (('예정', 'NNG'), 11),
#  (('밀', 'NNG'), 11),
#  (('단계', 'NNG'), 11),
#  (('가능', 'NNG'), 11),
#  (('40', 'SN'), 11),
#  (('세계', 'NNG'), 11),
#  (('대두', 'NNP'), 11),
#  (('후원', 'NNG'), 11),
#  (('약', 'MM'), 11),
#  (('부족', 'NNG'), 11),
#  (('전시', 'NNG'), 11),
#  (('반영', 'NNG'), 10),
#  (('집중', 'NNG'), 10),
#  (('구축', 'NNG'), 10),
#  (('강화', 'NNG'), 10),
#  (('큰', 'VA+ETM'), 10),
#  (('무단', 'NNG'), 10),
#  (('된다', 'XSV+EF'), 10),
#  (('자', 'XSN'), 10),
#  (('정부', 'NNG'), 10),
#  (('채널', 'NNG'), 10),
#  (('우리', 'NP'), 10),
#  (('쌀', 'NNG'), 10),
#  (('따라', 'VV+EC'), 10),
#  (('보', 'VX'), 10),
#  (('기록', 'NNG'), 10),
#  (('대표', 'NNG'), 10),
#  (('영상', 'NNG'), 10),
#  (('!', 'SF'), 10),
#  (('공략', 'NNG'), 10),
#  (('24', 'SN'), 10),
#  (('넘', 'VV'), 10),
#  (('000', 'SN'), 10),
#  (('학교', 'NNG'), 10),
#  (('면역', 'NNG'), 9),
#  (('발표', 'NNG'), 9),
#  (('사진', 'NNG'), 9),
#  (('감염증', 'NNG'), 9),
#  (('주', 'VX'), 9),
#  (('%,', 'SY'), 9),
#  (('안정', 'NNG'), 9),
#  (('운영', 'NNG'), 9),
#  (('간', 'NNB'), 9),
#  (('소비', 'NNG'), 9),
#  (('않', 'VX'), 9),
#  (('kr', 'SL'), 9),
#  (('전재', 'NNG'), 9),
#  (('대', 'NNBC'), 9),
#  (('가정', 'NNG'), 9),
#  (('비롯', 'XR'), 9),
#  (('시간', 'NNG'), 9),
#  (('기부', 'NNG'), 9),
#  (('편식', 'NNG'), 9),
#  (('진행', 'NNG'), 9),
#  (('비대', 'VV'), 9),
#  (('으며', 'EC'), 9),
#  (('과', 'JKB'), 9),
#  (('후', 'NNG'), 9),
#  (('동기', 'NNG'), 9),
#  (('20', 'SN'), 9),
#  (('개최', 'NNG'), 9),
#  (('거리', 'NNG'), 9),
#  (('필요', 'NNG'), 9),
#  (('있', 'VA'), 9),
#  (('바이오', 'NNP'), 9),
#  (('종합', 'NNG'), 9),
#  (('2019', 'SN'), 9),
#  (('총', 'MM'), 9),
#  (('최대', 'NNG'), 9),
#  (('액상', 'NNG'), 9),
#  (('아이', 'NNG'), 9),
#  (('급증', 'NNG'), 8),
#  (('주목', 'NNG'), 8),
#  (('바이러스', 'NNG'), 8),
#  (('들', 'VV'), 8),
#  (('t', 'SL'), 8),
#  (('지난해', 'NNG'), 8),
#  (('원료', 'NNG'), 8),
#  (('&', 'SY'), 8),
#  (('밥', 'NNG'), 8),
#  (('구독', 'NNG'), 8),
#  (('기반', 'NNG'), 8),
#  (('K', 'SL'), 8),
#  (('힘', 'NNG'), 8),
#  (('법', 'NNG'), 8),
#  (('정책', 'NNG'), 8),
#  (('미래', 'NNG'), 8),
#  (('적용', 'NNG'), 8),
#  (('전문', 'NNG'), 8),
#  (('이상', 'NNG'), 8),
#  (('기관', 'NNG'), 8),
#  (('진', 'XSA+ETM'), 8),
#  (('흥원', 'NNP'), 8),
#  (('세트', 'NNG'), 8),
#  (('크', 'VA'), 8),
#  (('지만', 'EC'), 8),
#  (('노력', 'NNG'), 8),
#  (('규모', 'NNG'), 8),
#  (('푸드', 'NNG'), 8),
#  (('지난달', 'NNG'), 8),
#  (('수급', 'NNG'), 8),
#  (('엄마', 'NNG'), 8),
#  (('수출액', 'NNG'), 8),
#  (('라면', 'NNG'), 8),
#  (('조', 'NR'), 8),
#  (('콩기름', 'NNG'), 8),
#  (('시험', 'NNG'), 8),
#  (('다는', 'ETM'), 8),
#  (('찜', 'NNG'), 8),
#  (('성적', 'NNG'), 8),
#  (('시책', 'NNG'), 8),
#  (('전시회', 'NNG'), 8),
#  (('편의점', 'NNG'), 8),
#  (('도시락', 'NNG'), 8),
#  (('관심', 'NNG'), 7),
#  (('신종', 'NNP'), 7),
#  (('내', 'NP+JKG'), 7),
#  (('품질', 'NNG'), 7),
#  (('우수', 'NNG'), 7),
#  (('농산물', 'NNG'), 7),
#  (('11', 'SN'), 7),
#  (('구매', 'NNG'), 7),
#  (('축산', 'NNG'), 7),
#  (('co', 'SL'), 7),
#  (('전국', 'NNG'), 7),
#  (('모두', 'MAG'), 7),
#  (('기회', 'NNG'), 7),
#  (('활용', 'NNG'), 7),
#  (('언론', 'NNG'), 7),
#  (('국회', 'NNG'), 7),
#  (('위기', 'NNG'), 7),
#  (('용', 'XSN'), 7),
#  (('사용', 'NNG'), 7),
#  (('정보', 'NNG'), 7),
#  (('시스템', 'NNG'), 7),
#  (('추천', 'NNG'), 7),
#  (('클러스터', 'NNG'), 7),
#  (('이번', 'NNG'), 7),
#  (('생활', 'NNG'), 7),
#  (('소개', 'NNG'), 7),
#  (('홈', 'NNG'), 7),
#  (('역시', 'MAJ'), 7),
#  (('았', 'EP'), 7),
#  (('수산물', 'NNG'), 7),
#  (('인', 'XSN'), 7),
#  (('함', 'XSA+ETN'), 7),
#  (('작년', 'NNG'), 7),
#  (('때문', 'NNB'), 7),
#  (('제일제당', 'NNP'), 7),
#  (('상황', 'NNG'), 7),
#  (('70', 'SN'), 7),
#  (('판매량', 'NNG'), 7),
#  (('진출', 'NNG'), 7),
#  (('종', 'NNG'), 7),
#  (('두기', 'NNG'), 7),
#  (('아니', 'VCN'), 7),
#  (('라', 'EC'), 7),
#  (('평가', 'NNG'), 7),
#  (('고', 'XPN'), 7),
#  (('자리', 'NNG'), 7),
#  (('해', 'VV+EC'), 7),
#  (('선발', 'NNG'), 7),
#  (('와', 'JKB'), 7),
#  (('단맛', 'NNG'), 7),
#  (('경남', 'NNP'), 7),
#  (('고성군', 'NNG'), 7),
#  (('톤', 'NNBC'), 7),
#  (('나', 'JC'), 7),
#  (('정도', 'NNG'), 7),
#  (('석유', 'NNG'), 7),
#  (('생명', 'NNG'), 7),
#  (('스', 'XSN'), 7),
#  (('RTD', 'SL'), 7),
#  (('프로', 'NNG'), 7),
#  (('심장병', 'NNG'), 7),
#  (('낮', 'VA'), 6),
#  (('발효', 'NNG'), 6),
#  (('인프라', 'NNG'), 6),
#  (('경쟁력', 'NNG'), 6),
#  (('투자', 'NNG'), 6),
#  (('식', 'NNB'), 6),
#  (('트렌드', 'NNG'), 6),
#  (('더욱', 'MAG'), 6),
#  (('홈페이지', 'NNG'), 6),
#  (('되', 'VV'), 6),
#  (('공감', 'NNG'), 6),
#  (('중점', 'NNG'), 6),
#  (('입법', 'NNG'), 6),
#  (('선정', 'NNG'), 6),
#  (('대책', 'NNG'), 6),
#  (('법안', 'NNG'), 6),
#  (('별', 'XSN'), 6),
#  (('극복', 'NNG'), 6),
#  (('급감', 'NNG'), 6),
#  (('개정', 'NNG'), 6),
#  (('률', 'XSN'), 6),
#  (('연장', 'NNG'), 6),
#  (('만큼', 'NNB'), 6),
#  (('비', 'XPN'), 6),
#  (('문제', 'NNG'), 6),
#  (('이라고', 'JKQ'), 6),
#  (('국가', 'NNG'), 6),
#  (('익산', 'NNP'), 6),
#  (('대전', 'NNG'), 6),
#  ((':', 'SC'), 6),
#  (('찾', 'VV'), 6),
#  (('초', 'NNB'), 6),
#  (('나가', 'VX'), 6),
#  (('키트', 'NNP'), 6),
#  (('킷', 'NNP'), 6),
#  (('사람', 'NNG'), 6),
#  (('프레시', 'NNP'), 6),
#  (('상반기', 'NNG'), 6),
#  (('양식', 'NNG'), 6),
#  (('신', 'XPN'), 6),
#  (('는데', 'EC'), 6),
#  (('배송', 'NNG'), 6),
#  (('전', 'NNG'), 6),
#  (('현장', 'NNG'), 6),
#  (('에선', 'JKB+JX'), 6),
#  (('볼', 'VX+ETM'), 6),
#  (('인해', 'VV+EC'), 6),
#  (('영향', 'NNG'), 6),
#  (('류', 'XSN'), 6),
#  (('커머스', 'NNG'), 6),
#  (('라이프', 'NNG'), 6),
#  (('스타일', 'NNG'), 6),
#  (('탄생', 'NNG'), 6),
#  (('라고', 'EC'), 6),
#  (('다고', 'EC'), 6),
#  (('설명', 'NNG'), 6),
#  (('연간', 'NNG'), 6),
#  (('지속', 'NNG'), 6),
#  (('센터', 'NNG'), 6),
#  (('국물', 'NNG'), 6),
#  (('조개', 'NNG'), 6),
#  (('■', 'SY'), 6),
#  (('된다', 'VV+EF'), 6),
#  (('는다', 'EF'), 6),
#  (('공장', 'NNG'), 6),
#  (('는데요', 'EF'), 6),
#  (('정유', 'NNG'), 6),
#  (('의료', 'NNG'), 6),
#  (('현상', 'NNG'), 6),
#  (('교과', 'NNG'), 6),
#  (('실기', 'NNG'), 6),
#  (('60', 'SN'), 6),
#  (('장학금', 'NNG'), 6),
#  (('건', 'NNBC'), 6),
#  (('매출액', 'NNG'), 6),
#  (('빙그레', 'MAG'), 6),
#  (('굿', 'NNP'), 6),
#  (('윌스', 'NNP'), 6),
#  (('토어', 'NNG'), 6),
#  (('경상북도', 'NNP'), 5),
#  (('방안', 'NNG'), 5),
#  (('가운데', 'NNG'), 5),
#  (('채소', 'NNG'), 5),
#  (('농수산', 'NNG'), 5),
#  (('올', 'MM'), 5),
#  (('D', 'SL'), 5),
#  (('홍보', 'NNG'), 5),
#  (('시설', 'NNG'), 5),
#  (('현대', 'NNG'), 5),
#  (('진흥', 'NNG'), 5),
#  (('식생활', 'NNG'), 5),
#  (('이미지', 'NNG'), 5),
#  (('알려', 'VV+EC'), 5),
#  (('도록', 'EC'), 5),
#  (('안', 'NNG'), 5),
#  (('만들', 'VV'), 5),
#  (('유명', 'NNG'), 5),
#  (('>', 'SY'), 5),
#  (('정기', 'NNG'), 5),
#  (('과제', 'NNG'), 5),
#  (('방지법', 'NNP'), 5),
#  (('이날', 'NNG'), 5),
#  (('일부', 'NNG'), 5),
#  (('단체', 'NNG'), 5),
#  (('2020', 'SN'), 5),
#  (('21', 'SN'), 5),
#  (('민생', 'NNG'), 5),
#  (('공정', 'NNG'), 5),
#  (('부담', 'NNG'), 5),
#  (('했', 'VX+EP'), 5),
#  (('한다는', 'XSV+ETM'), 5),
#  (('가족', 'NNG'), 5),
#  (('일', 'NNG'), 5),
#  (('주택', 'NNG'), 5),
#  (('장기', 'NNG'), 5),
#  (('규정', 'NNG'), 5),
#  (('소득', 'NNG'), 5),
#  (('제', 'XSN'), 5),
#  (('제시', 'NNG'), 5),
#  (('인사', 'NNG'), 5),
#  (('법인', 'NNG'), 5),
#  (('실시', 'NNG'), 5),
#  (('50', 'SN'), 5),
#  (('특히', 'MAG'), 5),
#  (('환경', 'NNG'), 5),
#  (('쇼핑', 'NNG'), 5),
#  (('시대', 'NNG'), 5),
#  (('최초', 'NNG'), 5),
#  (('TV', 'SL'), 5),
#  (('모음', 'NNG'), 5),
#  (('속', 'NNG'), 5),
#  (('때', 'NNG'), 5),
#  (('장마', 'NNG'), 5),
#  (('잘', 'MAG'), 5),
#  (('선택', 'NNG'), 5),
#  (('’,', 'SY'), 5),
#  (('세상', 'NNG'), 5),
#  (('닷컴', 'NNP'), 5),
#  (('경쟁', 'NNG'), 5),
#  (('이유', 'NNG'), 5),
#  (('라며', 'EC'), 5),
#  (('차지', 'NNG'), 5),
#  (('권', 'XSN'), 5),
#  (('이', 'VV'), 5),
#  (('서비스', 'NNG'), 5),
#  (('됐', 'VV+EP'), 5),
#  (('살', 'NNG'), 5),
#  (('주요', 'NNG'), 5),
#  (('유', 'NNP'), 5),
#  (('튜버', 'NNP'), 5),
#  (('뿐', 'JX'), 5),
#  (('%)', 'SY'), 5),
#  (('더불', 'VV'), 5),
#  (('영양', 'NNG'), 5),
#  (('여러분', 'NP'), 5),
#  (('체험', 'NNG'), 5),
#  (('헤럴드', 'NNP'), 5),
#  (('맞', 'VV'), 5),
#  (('내', 'NNB'), 5),
#  (('문화', 'NNG'), 5),
#  (('LABS', 'SL'), 5),
#  (('용품', 'NNG'), 5),
#  (('목욕탕', 'NNG'), 5),
#  (('레시피', 'NNG'), 5),
#  (('뒤', 'NNG'), 5),
#  (('전반', 'NNG'), 5),
#  (('장점', 'NNG'), 5),
#  (('25', 'SN'), 5),
#  (('피부', 'NNG'), 5),
#  (('또한', 'MAJ'), 5),
#  (('일정', 'NNG'), 5),
#  (('한다', 'XSV+EC'), 5),
#  (('고성', 'NNG'), 5),
#  (('단백질', 'NNG'), 5),
#  (('주', 'VV'), 5),
#  (('껍데기', 'NNG'), 5),
#  (('곳', 'NNG'), 5),
#  (('물', 'NNG'), 5),
#  (('대신', 'NNG'), 5),
#  (('MBC', 'SL'), 5),
#  (('가동', 'NNG'), 5),
#  (('공업', 'NNG'), 5),
#  (('해야', 'XSV+EC'), 5),
#  (('어려움', 'NNG'), 5),
#  (('모습', 'NNG'), 5),
#  (('인재', 'NNG'), 5),
#  (('입학', 'NNG'), 5),
#  (('비교', 'NNG'), 5),
#  (('실적', 'NNG'), 5),
#  (('전문점', 'NNG'), 5),
#  (('프랜차이즈', 'NNG'), 5),
#  (('기존', 'NNG'), 5),
#  (('성장세', 'NNG'), 5),
#  (('함유', 'NNG'), 5),
#  (('푸르밀', 'NNP'), 5),
#  (('헛', 'XPN'), 5),
#  (('보리차', 'NNG'), 5),
#  (('보리', 'NNG'), 5),
#  (('완치', 'NNG'), 5),
#  (('재단', 'NNG'), 5),
#  (('내수', 'NNG'), 4),
#  (('2024', 'SN'), 4),
#  (('1283', 'SN'), 4),
#  (('동시', 'NNG'), 4),
#  (('중심지', 'NNG'), 4),
#  (('전략', 'NNG'), 4),
#  (('교수', 'NNG'), 4),
#  (('는다', 'EC'), 4),
#  (('제고', 'NNG'), 4),
#  (('소', 'NNG'), 4),
#  (('담회', 'NNG'), 4),
#  (('청소년', 'NNG'), 4),
#  (('22', 'SN'), 4),
#  (('발전', 'NNG'), 4),
#  (('외', 'NNB'), 4),
#  (('끌', 'VV'), 4),
#  (('열풍', 'NNG'), 4),
#  (('활성', 'NNG'), 4),
#  (('www', 'SL'), 4),
#  (('추세', 'NNG'), 4),
#  (('예방', 'NNG'), 4),
#  (('newsis', 'SL'), 4),
#  (('미술', 'NNG'), 4),
#  (('공개', 'NNG'), 4),
#  (('부동산', 'NNG'), 4),
#  (('참석', 'NNG'), 4),
#  (('안전', 'NNG'), 4),
#  (('실현', 'NNG'), 4),
#  (('제', 'XPN'), 4),
#  (('중단', 'NNG'), 4),
#  (('포함', 'NNG'), 4),
#  (('세', 'MM'), 4),
#  (('확인', 'NNG'), 4),
#  (('해당', 'NNG'), 4),
#  (('일반', 'NNG'), 4),
#  (('인원', 'NNG'), 4),
#  (('적극', 'NNG'), 4),
#  (('시키', 'XSV'), 4),
#  (('입주', 'NNG'), 4),
#  (('됩니다', 'XSV+EF'), 4),
#  (('바이어', 'NNG'), 4),
#  (('맞춰', 'VV+EC'), 4),
#  (('23', 'SN'), 4),
#  (('고민', 'NNG'), 4),
#  (('태풍', 'NNG'), 4),
#  (('직접', 'MAG'), 4),
#  (('농림', 'NNG'), 4),
#  (('한다고', 'XSV+EC'), 4),
#  (('쉽', 'VA'), 4),
#  (('배', 'NNG'), 4),
#  (('발굴', 'NNG'), 4),
#  (('간편', 'XR'), 4),
#  (('전망', 'NNG'), 4),
#  (('SSG', 'SL'), 4),
#  (('쿡', 'NNP'), 4),
#  (('음식', 'NNG'), 4),
#  (('지', 'NNP'), 4),
#  (('수도', 'NNG'), 4),
#  (('중심', 'NNG'), 4),
#  (('유지', 'NNG'), 4),
#  (('조리', 'NNG'), 4),
#  (('내', 'VV'), 4),
#  (('경험', 'NNG'), 4),
#  (('가득', 'MAG'), 4),
#  (('메뉴', 'NNG'), 4),
#  (('포장', 'NNG'), 4),
#  (('선보이', 'VV'), 4),
#  (('차별', 'NNG'), 4),
#  (('편', 'NNB'), 4),
#  (('축하', 'NNG'), 4),
#  (('전달', 'NNG'), 4),
#  (('싶', 'VX'), 4),
#  (('꼽', 'VV'), 4),
#  (('줄', 'VV'), 4),
#  (('데', 'NNB'), 4),
#  (('%),', 'SY'), 4),
#  (('대상그룹', 'NNP'), 4),
#  (('보유', 'NNG'), 4),
#  (('현재', 'NNG'), 4),
#  (('효과', 'NNG'), 4),
#  (('12', 'SN'), 4),
#  (('늘어날', 'VV+ETM'), 4),
#  (('만든', 'VV+ETM'), 4),
#  (('사랑', 'NNG'), 4),
#  (('전', 'MM'), 4),
#  (('불', 'XPN'), 4),
#  (('빠르', 'VA'), 4),
#  (('\xa0', 'SY'), 4),
#  (('특성', 'NNG'), 4),
#  (('기여', 'NNG'), 4),
#  (('2018', 'SN'), 4),
#  (('인디애나', 'NNP'), 4),
#  (('대두', 'NNG'), 4),
#  (('지원자', 'NNG'), 4),
#  (('26', 'SN'), 4),
#  (('시상식', 'NNG'), 4),
#  (('이전', 'NNG'), 4),
#  (('롯데', 'NNP'), 4),
#  (('대', 'NNG'), 4),
#  (('가', 'VX'), 4),
#  (('였', 'VCP+EP'), 4),
#  (('15', 'SN'), 4),
#  (('왔', 'VX+EP'), 4),
#  (('2021', 'SN'), 4),
#  (('내년', 'NNG'), 4),
#  (('꾸준히', 'MAG'), 4),
#  (('가을', 'NNG'), 4),
#  (('◇', 'SY'), 4),
#  (('산', 'XSN'), 4),
#  (('생산량', 'NNG'), 4),
#  (('형성', 'NNG'), 4),
#  (('칼로리', 'NNG'), 4),
#  (('회무', 'NNG'), 4),
#  (('침', 'NNG'), 4),
#  (('많이', 'MAG'), 4),
#  (('통계', 'NNG'), 4),
#  (('마다', 'JX'), 4),
#  (('영양가', 'NNG'), 4),
#  (('다른', 'MM'), 4),
#  (('성분', 'NNG'), 4),
#  (('할', 'VV+ETM'), 4),
#  (('확보', 'NNG'), 4),
#  (('입니다', 'VCP+EF'), 4),
#  (('이나', 'JC'), 4),
#  (('이어', 'MAG'), 4),
#  (('이달', 'NNG'), 4),
#  (('문', 'NNG'), 4),
#  (('부산물', 'NNG'), 4),
#  (('충전', 'NNG'), 4),
#  (('부산일보', 'NNP'), 4),
#  (('얻', 'VV'), 4),
#  (('급격', 'XR'), 4),
#  (('감소', 'NNG'), 4),
#  (('전공', 'NNG'), 4),
#  (('대', 'XSV'), 4),
#  (('수시', 'NNG'), 4),
#  (('교차', 'NNG'), 4),
#  (('다면', 'EC'), 4),
#  (('서류', 'NNG'), 4),
#  (('＊', 'SY'), 4),
#  (('접수', 'NNG'), 4),
#  (('고자', 'EC'), 4),
#  (('항공', 'NNG'), 4),
#  (('17', 'SN'), 4),
#  (('Q', 'SL'), 4),
#  (('무엇', 'NP'), 4),
#  (('A', 'SL'), 4),
#  (('어요', 'EF'), 4),
#  (('죠', 'EF'), 4),
#  (('한겨레', 'NNG'), 4),
#  (('서천군', 'NNG'), 4),
#  (('따른', 'VV+ETM'), 4),
#  (('경기', 'NNG'), 4),
#  (('지금', 'NNG'), 4),
#  (('취식', 'NNG'), 4),
#  (('급식', 'NNG'), 4),
#  (('특허', 'NNG'), 4),
#  (('식음료', 'NNG'), 4),
#  (('플레인', 'NNG'), 4),
#  (('생각', 'NNG'), 4),
#  (('빙그레', 'NNP'), 4),
#  (('매일', 'MAG'), 4),
#  (('편', 'NNBC'), 4),
#  (('?', 'SF'), 4),
#  (('대용', 'NNG'), 4),
#  (('개차', 'NNG'), 4),
#  (('천', 'NR'), 4),
#  (('하이트진로', 'NNP'), 4),
#  (('수술비', 'NNG'), 4),
#  (('임직원', 'NNG'), 4),
#  (('임가공', 'NNG'), 4),
#  (('물품', 'NNG'), 4),
#  (('제대로', 'MAG'), 3),
#  (('면역력', 'NNG'), 3),
#  (('입', 'NNG'), 3),
#  (('안동', 'NNP'), 3),
#  (('프랑스', 'NNP'), 3),
#  (('부스', 'NNG'), 3),
#  (('케', 'XSV+EC'), 3),
#  (('공사', 'NNG'), 3),
#  (('량', 'NNG'), 3),
#  (('R', 'SL'), 3),
#  ((';', 'SY'), 3),
#  (('먼저', 'MAG'), 3),
#  (('반', 'NNG'), 3),
#  (('보급', 'NNG'), 3),
#  (('쇼핑몰', 'NNG'), 3),
#  (('수출상', 'NNG'), 3),
#  (('계약', 'NNG'), 3),
#  (('재배', 'NNG'), 3),
#  (('늘리', 'VV'), 3),
#  (('농어촌', 'NNG'), 3),
#  (('투입', 'NNG'), 3),
#  (('국장', 'NNG'), 3),
#  (('김', 'NNP'), 3),
#  (('일보', 'NNG'), 3),
#  (('높이', 'VV'), 3),
#  (('일본', 'NNP'), 3),
#  (('이런', 'MM'), 3),
#  (('☞', 'SY'), 3),
#  (('Artprice', 'SL'), 3),
#  (('작품', 'NNG'), 3),
#  (('빅', 'NNP'), 3),
#  (('데이터', 'NNG'), 3),
#  (('MSI', 'SL'), 3),
#  (('주가', 'NNG'), 3),
#  (('시세표', 'NNG'), 3),
#  (('<ⓒ', 'SY'), 3),
#  (('통신사', 'NNG'), 3),
#  (('윤미향', 'NNP'), 3),
#  (('오거돈', 'NNP'), 3),
#  (('위원장', 'NNG'), 3),
#  (('열린', 'VV+ETM'), 3),
#  (('위원회', 'NNG'), 3),
#  (('길', 'ETN+JKO'), 3),
#  (('두', 'MM'), 3),
#  (('첫', 'MM'), 3),
#  (('당', 'NNG'), 3),
#  (('력', 'XSN'), 3),
#  (('경감', 'NNG'), 3),
#  (('희망', 'NNG'), 3),
#  (('환자', 'NNG'), 3),
#  (('시', 'NNB'), 3),
#  (('구입', 'NNG'), 3),
#  (('농촌', 'NNG'), 3),
#  (('보호', 'NNG'), 3),
#  (('고용', 'NNG'), 3),
#  (('각종', 'NNG'), 3),
#  (('담', 'VV'), 3),
#  (('폐지', 'NNG'), 3),
#  (('근로', 'NNG'), 3),
#  (('카드', 'NNG'), 3),
#  (('특례', 'NNG'), 3),
#  (('목표', 'NNG'), 3),
#  (('형', 'XSN'), 3),
#  (('공공', 'NNG'), 3),
#  (('과정', 'NNG'), 3),
#  (('자연', 'NNG'), 3),
#  (('여성', 'NNG'), 3),
#  (('범죄', 'NNG'), 3),
#  (('원', 'NNG'), 3),
#  (('청년', 'NNG'), 3),
#  (('먹거리', 'NNG'), 3),
#  (('일자리', 'NNG'), 3),
#  (('개막', 'NNG'), 3),
#  (('회', 'NNBC'), 3),
#  (('42', 'SN'), 3),
#  (('301', 'SN'), 3),
#  (('입점', 'NNG'), 3),
#  (('연합뉴스', 'NNP'), 3),
#  (('추석', 'NNG'), 3),
#  (('해결', 'NNG'), 3),
#  (('나', 'JX'), 3),
#  (('과일', 'NNG'), 3),
#  (('뛰', 'VV'), 3),
#  (('충남', 'NNP'), 3),
#  (('창업', 'NNG'), 3),
#  (('가치', 'NNG'), 3),
#  (('차', 'NNBC'), 3),
#  (('시기', 'NNG'), 3),
#  (('될', 'XSV+ETM'), 3),
#  (('눈', 'NNG'), 3),
#  (('불', 'NNG'), 3),
#  (('요리법', 'NNG'), 3),
#  (('SPC', 'SL'), 3),
#  (('삼립', 'NNG'), 3),
#  (('그린', 'VV+ETM'), 3),
#  (('치열', 'NNG'), 3),
#  (('된', 'VV+ETM'), 3),
#  (('미리', 'MAG'), 3),
#  (('신선', 'XR'), 3),
#  (('식', 'NNG'), 3),
#  (('인', 'NNG'), 3),
#  (('확진', 'NNG'), 3),
#  (('28', 'SN'), 3),
#  (('가지', 'NNBC'), 3),
#  (('현재', 'MAG'), 3),
#  (('로부터', 'JKB'), 3),
#  (('최고', 'NNG'), 3),
#  (('참여', 'NNG'), 3),
#  (('원물', 'NNG'), 3),
#  (('새벽', 'NNG'), 3),
#  (('앞', 'NNG'), 3),
#  (('광동', 'NNG'), 3),
#  (('과', 'NNG'), 3),
#  (('고급', 'NNG'), 3),
#  (('즐길', 'VV+ETM'), 3),
#  (('수준', 'NNG'), 3),
#  (('하반기', 'NNG'), 3),
#  (('어', 'IC'), 3),
#  (('단순히', 'MAG'), 3),
#  (('밖', 'NNG'), 3),
#  (('접속', 'NNG'), 3),
#  (('사', 'NR'), 3),
#  (('윤태진', 'NNP'), 3),
#  (('이마트', 'NNP'), 3),
#  (('몰', 'NNG'), 3),
#  (('보이', 'VV'), 3),
#  (('돼', 'XSV+EC'), 3),
#  (('인력', 'NNG'), 3),
#  (('여파', 'NNG'), 3),
#  (('구성', 'NNG'), 3),
#  (('간식', 'NNG'), 3),
#  (('행복', 'NNG'), 3),
#  (('시', 'EP'), 3),
#  (('화상', 'NNG'), 3),
#  (('나라', 'NNG'), 3),
#  (('늘어난', 'VV+ETM'), 3),
#  (('새로운', 'VA+ETM'), 3),
#  (('했', 'XSA+EP'), 3),
#  (('신선', 'NNG'), 3),
#  (('어도', 'EC'), 3),
#  (('자회사', 'NNG'), 3),
#  (('엔', 'JKB+JX'), 3),
#  (('접목', 'NNG'), 3),
#  (('기대', 'NNG'), 3),
#  (('라는', 'ETM'), 3),
#  (('라는', 'VCP+ETM'), 3),
#  (('의미', 'NNG'), 3),
#  (('니즈', 'NNG'), 3),
#  (('케어', 'NNG'), 3),
#  (('글로벌', 'NNG'), 3),
#  (('가지', 'VV'), 3),
#  (('전했', 'VV+EP'), 3),
#  (('보였', 'VV+EP'), 3),
#  (('롱', 'NNG'), 3),
#  (('드리', 'NNG'), 3),
#  (('즐기', 'VV'), 3),
#  (('스킨케어', 'NNG'), 3),
#  (('미용', 'NNG'), 3),
#  (('분', 'NNBC'), 3),
#  (('저작권자', 'NNG'), 3),
#  (('다소', 'MAG'), 3),
#  (('모든', 'MM'), 3),
#  (('올레산', 'NNG'), 3),
#  (('여', 'EC'), 3),
#  (('끝', 'NNG'), 3),
#  (('전하', 'VV'), 3),
#  (('회장', 'NNG'), 3),
#  (('동안', 'NNG'), 3),
#  (('대해', 'VV+EC'), 3),
#  (('시식', 'NNG'), 3),
#  (('선호도', 'NNG'), 3),
#  (('13', 'SN'), 3),
#  (('통해서', 'VV+EC'), 3),
#  (('전개', 'NNG'), 3),
#  (('찬바람', 'NNG'), 3),
#  (('불', 'VV'), 3),
#  (('다이어트', 'NNG'), 3),
#  (('쫄깃', 'XR'), 3),
#  (('하늘', 'NNG'), 3),
#  (('다양', 'XR'), 3),
#  (('여러', 'MM'), 3),
#  (('헤엄치', 'VV'), 3),
#  (('성군', 'NNG'), 3),
#  (('풍부', 'XR'), 3),
#  (('홍', 'NNG'), 3),
#  (('2013', 'SN'), 3),
#  (('해', 'NNG'), 3),
#  (('없이', 'MAG'), 3),
#  (('돕', 'VV'), 3),
#  (('해감', 'NNG'), 3),
#  (('이용', 'NNG'), 3),
#  ...]

# %%
stopPos = ['JKO', 'JKB', 'EC', 'JX', 'EF', 'SY', 'SN', 'XSV+EP', 'XSV+ETM', 'JC', 'SN', 'SSO', 'SSC','MAJ', 'VV']
stopWord = ['코로나', '▶', '은', '가', '건', '것', '이', '있', '하', '같', 't', '만', '저작권자', '연합뉴스TV', '뉴시스', '국민일보' '세계일보', '서울경제' '조선비즈', '헤럴드경제']

food_article = []
for tag in mecab_tag:
    if tag[1] not in stopPos:
        if tag[0] not in stopWord:
            food_article.append(tag[0])
print(food_article)
# Out:
# ['경북', ',', '면역', '효자', '김치', '산업', '제대로', '키운다', '면역력', '관심', '반영', '수출', '·', '내수', '급증', '…', '년', '억', '투', '입', '집중', '육성', '경', '북도', '최근', '면역', '강화식품', '주목', '는', '김치', '산업', '집중', '육성', '기', '위해', '경상북도', '김치', '산업', '육성', '방안', '발표', '.', '사진', '안동', '풍산', '농협', '김치', '.', '안', '동시', '제공', '경', '북도', '김치', '산업', '의', '중심지', '거듭', '난다는', '전략', '마련', '.', '경북', '면역', '강화식품', '주목', '는', '김치', '산업', '집중', '육성', '기', '위한', '경상북도', '김치', '산업', '육성', '방안', '일', '발표', '.', '신종', '바이러스', '감염증', '확산', '건강', '대한', '관심', '면역력', '높여', '주', '는', '식품', '주목', '는', '가운데', '최근', '김치', '수출', '급증', '.', '프랑스', '몽펠리에', '대학', '장', '부스', '케', '교수', '사망률', '상대', '적', '낮', '한국', '독일', '공통', '적', '발효', '채소', '연구', '결과', '발표', '이후', '다', '.', '한국', '농수산', '식품', '유통', '공사', '의', '국내', '김치', '수출', '현황', '올', '월', '달러', '지난해', '기간', '의', ',', '달러', '비해', '수출', '량', '수출', '금액', '증가', '.', '기간', '경북', '내', '수출', ',', '달러', ',', '달러', '늘어났', '.', '경북', '경상북도', '김치', '산업', '육성', '방안', '수립', '년', '인프라', '구축', ',', '품질', '경쟁력', '제고', ',', '내수', '해외', '시장', '확대', ',', '원료', '의', '안정', '적', '공급', ',', 'R', 'D', '지원', '홍보', '등', '개', '분야', '억', '원', '투자', '해', '김치', '산업', '육성', '총력', '기울인다', '.', '먼저', '김치', '등', '농', '식품', '가공', '업체', '시설', '현대', '화', '지원', '는', '농', '식품', '가공', '육성', '사업', ',', '식품', '소재', '반', '가공', '산업', '육성', '사업', '등', '억', '원', '투자', '해', '농', '식품', '가공', '시설', '인프라', '구축', '한다', '.', '또', '김치', '맛', '표준', '화', '위한', '등급', '화', ',', '김치', '우수', '종균', '보급', ',', '경북', '우수', '농산물', '브랜드', '지원', '등', '억', '원', '지원', '해', '품질', '경쟁력', '강화', '한다', '.', '최근', '증가', '는', '식', '재료', '온라인', '구매', ',', '혼', '밥', '·', '집', '밥', '트렌드', '반영', '해', '경북', '온라인', '쇼핑몰', '사이', '소', '김치', '특별', '관', '운영', '수출상', '담회', '물류비', '지원', '사업', '등', '억', '원', '지원', '해', '수출', '급증', '는', '해외', '시장', '더욱', '확대', '계획', '.', '김치', '의', '안정', '적', '공급', '위해', '생산자', '기업', '간', '계약', '재배', '농어촌', '진흥', '기금', '채소', '가격', '안정', '지원', '사업', '등', '억', '원', '투입', '한다', '.', '신상품', '개발', '지원', '해', '어린이', '·', '청소년', '대상', '식생활', '교육', '사업', ',', '김장', '행사', '통한', '경상북도', '생산', '김치', '의', '이미지', '제고', '등', '김치', '분야', 'R', 'D', '홍보', '분야', '억', '원', '지원', '해', '경상북도', '김치', '산업', '의', '중심지', '발전', '시켜', '나갈', '방침', '.', '김종수', '경북', '농', '축산', '유통', '국장', '최근', '김치', '발효', '건강', '식품', '국내', '·', '외', '알려', '지', '큰', '인기', '집', '밥', '열풍', '국내', '소비', '증가', '김치', '산업', '더욱', '발전', '수', '내수', '시장', '확대', '수출', '활성', '화', '위한', '지원', '않', '겠', '고', '밝혔', '.', '안동', '김', '재산', '기자', 'jskimkb', 'kmib', 'co', 'kr', '네이버', '국민', '일보', '구독', '세요', '클릭', '국민', '일보', '홈페이지', 'GoodNews', 'paper', '국민', '일보', 'www', 'kmib', 'co', 'kr', ',', '무단', '전재', '재', '배포', '금지', '경북', '김치', '산업', '중심지', '될', '년', '간', '억', '원', '투입', '풍산', '김치', '사진', '안', '동시', '제공', '안동', '류상현', '기자', '경북', '도', '김치', '산업', '육성', '나선다', '일', '경북', '도', '확산', '면역력', '높여', '주', '는', '식품', '들', '주목', '는', '가운데', '프랑스', '몽펠리에', '대', '장', '부스', '케', '교수', '의', '사망률', '상대', '적', '낮', '한국', '독일', '공통', '적', '발효', '채소', '연구', '발표', '이후', '전통', '발효', '식품', '인', '김치', '의', '수출', '급증', '.', '지난해', '월', '전국', ',', '달러', '의', '김치', '수출', '됐으나', '올해', '기간', '증가', ',', '달러', '증가', '었', '.', '경북', '기간', ',', '달러', ',', '달러', '었', '.', '추세', '반영', '해', '경북', '김치', '산업', '육성', '방안', '마련', '년', '년', '간', '산업', '기반', '구축', '품질', '경쟁력', '제고', '내수', '해외', '시장', '확대', '원료', '의', '안정', '적', '공급', 'R', 'D', '홍보', '지원', '등', '개', '분야', '억', '원', '투자', '기', '했', '.', '먼저', '김치', '등', '농', '식품', '가공', '업체', '시설', '현대', '화', '지원', '는', '농', '식품', '가공육', '성', '사업', ',', '식품', '소재', '반', '가공', '산업', '육성', '사업', '등', '억', '원', '투자', '해', '농', '식품', '가공', '시설', '기반', '구축', '나선다', '.', '또', '김치', '맛', '표준', '화', '위한', '등급', '화', ',', '김치', '우수', '종균', '보급', ',', '경북', '우수', '농산물', '브랜드', '화', '등', '억', '원', '지원', '해', '품질', '경쟁력', '기', '했', '.', '식', '재료', '온라인', '구매', ',', '혼', '밥', '·', '집', '밥', '수요', '증가', '추세', '반영', '해', '경북', '온라인', '쇼핑몰', '인', '사이', '소', '김치', '특별', '관', '운영', ',', '수출상', '담회', '물류비', '지원', '사업', '등', '억', '원', '지원 ...

# %% [markdown]
# ## 별도) 키워드 추출하기

# %%
from konlpy.tag import Mecab 
mecab = Mecab()

mecab_tokens2 = []
for i in range(len(food_news)):
        mecab_tokens2.append(mecab.nouns(food_news['title'][i])) #토큰화하면서 품사부착 동시에 해줄 수 있음 
        mecab_tokens2.append(mecab.nouns(food_news["content"][i]))

mecab_tag2 = []
for token in mecab_tokens2: 
    mecab_tag2 += token

# %%
from collections import Counter 
KW = Counter(mecab_tag2).most_common()
food_df = pd.DataFrame(KW, columns = ['단어', '언급횟수'])
food_df = food_df.nlargest(110, '언급횟수')
food_df.tail(30)
# Out:
#        단어  언급횟수
# 80     관련    16
# 81      중    16
# 82     출시    16
# 83     협회    16
# 84     면접    16
# 85     대학    15
# 86     유통    15
# 87     기간    15
# 88     축제    15
# 89     뉴스    15
# 90   프로그램    15
# 91     대두    15
# 92     육성    14
# 93     제공    14
# 94     확산    14
# 95      장    14
# 96     가공    14
# 97     교육    14
# 98     요리    14
# 99     전년    14
# 100     점    14
# 101    기능    14
# 102  고압가스    14
# 103    계획    13
# 104     대    13
# 105    성장    13
# 106    준비    13
# 107    피해    13
# 108    시작    13
# 109    상품    13

# %%
food_df.to_csv('C:/Users/이상은/top50_keywords.csv')

# %% [markdown]
# ## top 50위 단어들을 가지고 워드클라우드 만들기

# %%
import matplotlib.pyplot as pPlot
from wordcloud import WordCloud, STOPWORDS
import numpy as npy
from PIL import Image
dataset = open("C:/Users/이상은/top50_keywords.csv", "r").read()
# Out:
# '단어,언급횟수\n지원,52\n가리비,48\n시장,44\n김치,43\n학생,32\n온라인,31\n수출,30\n오뚜기,30\n개,29\n경제,29\n미국,25\n탄산,25\n농,24\n국내,23\n집,23\n키트,23\n건강,22\n증가,22\n확대,21\n간,21\n위,21\n마스터,21\n유산균,21\n말,20\n사회,20\n차,20\n분야,19\n생산,19\n호서,19\n행사,18\n사태,18\n아이스크림,18\n경북,17\n맛,17\n브랜드,17\n어린이,17\n서울,17\n달러,16\n해외,16\n축제,15\n대두,15\n확산,14\n장,14\n가공,14\n교육,14\n"요리\t",14\n고압가스,14\n성장,13\n피해,13\n'

# %%
#한글은 깨지기 때문에 C드라이브 > fonts 검색 > 맑은 고딕 등 > 바탕화면에 불어넣기 > 아래 path 입력하기 
path = 'malgun.ttf'
import matplotlib.font_manager as fm
fontprop = fm.FontProperties(fname=path)

def create_word_cloud(string):
    maskArray = npy.array(Image.open("C:/Users/이상은/shape.png"))
    cloud = WordCloud(font_path =path, background_color = "white", width=800, height=600)
    cloud.generate(string)
    cloud.to_file("C:/Users/이상은/wordCloud.png")
    pPlot.figure(figsize=(10,8))
    pPlot.imshow(cloud, interpolation = 'bilinear')
    return pPlot.show()

dataset = dataset.lower()
create_word_cloud(dataset)
